# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_excel("indo_12_1.xls", skiprows=3, na_values='-')
df.head(10)
df.isnull().sum()
df = df.fillna(0)
df.isnull().sum()
df.head(10)
df['provinsi'] = df.iloc[:,0]
df.head(10)
# len(df)
# np.full((1, 36), 10)
# Out:
#                   Unnamed: 0       1971       1980        1990        1995  \
# 0                       Aceh  2008595.0  2611271.0   3416156.0   3847583.0
# 1             Sumatera Utara  6621831.0  8360894.0  10256027.0  11114667.0
# 2             Sumatera Barat  2793196.0  3406816.0   4000207.0   4323170.0
# 3                       Riau  1641545.0  2168535.0   3303976.0   3900534.0
# 4                      Jambi  1006084.0  1445994.0   2020568.0   2369959.0
# 5           Sumatera Selatan  3440573.0  4629801.0   6313074.0   7207545.0
# 6                   Bengkulu   519316.0   768064.0   1179122.0   1409117.0
# 7                    Lampung  2777008.0  4624785.0   6017573.0   6657759.0
# 8  Kepulauan Bangka Belitung        0.0        0.0         0.0         0.0
# 9             Kepulauan Riau        0.0        0.0         0.0         0.0
#
#          2000        2010                   provinsi
# 0   3930905.0   4494410.0                       Aceh
# ...

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(231, projection='3d')

i = 1
x = np.arange(len(df))
y = np.arange(10)
z = np.zeros(10)

dx = np.ones(len(df))
dy = np.ones(10)
dz = df.iloc[:,1] # data

plt.title("Jumlah Penduduk 1971")
ax.bar3d(x,y,z, dx, dy,dz)
ax.set_zlabel("Jumlah Penduduk", )
# ax.set_yticks(df['provinsi'])
ax.set_yticklabels(df['provinsi'])
# ax.set_

plt.show()
# Out:
# c:\users\nadian\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2480: UserWarning: x, y, and z must be the same length.
#   warnings.warn('x, y, and z must be the same length.')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-81f64fe5a4c1> in <module>()
#      12
#      13 plt.title("Jumlah Penduduk 1971")
# ---> 14 ax.bar3d(x,y,z, dx, dy,dz)
#      15 ax.set_zlabel("Jumlah Penduduk", )
#      16 # ax.set_yticks(df['provinsi'])
#
# c:\users\nadian\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in bar3d(self, x, y, z, dx, dy, dz, color, zsort, *args, **kwargs)
#    2525
#    2526         normals = self._generate_normals(polys)
# -> 2527         sfacecolors = self._shade_colors(facecolors, normals)
#    2528         col = art3d.Poly3DCollection(polys,
#    2529                                      zsort=zsort,
#
# ...
